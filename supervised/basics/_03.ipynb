# %% [markdown]
# <a href="https://colab.research.google.com/github/strzelnat/machine_learning_study/blob/main/supervised/basics/_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}


df = pd.DataFrame(data = data)
df_copy = df.copy()

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
df.isnull().sum()
# Out:
# size      1
# color     0
# gender    1
# price     1
# weight    2
# bought    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(5)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer  = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
df[['size', 'gender']] = imputer.fit_transform(df[['size', 'gender']])
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue  female    NaN   300.0    yes
# 3    M  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
imputer  = SimpleImputer(missing_values = np.nan, strategy = 'mean')
df[['price', 'weight']] = imputer.fit_transform(df[['price', 'weight']])
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue  female  117.0   300.0    yes
# 3    M  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le =LabelEncoder()
df['bought'] = le.fit_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0   450.0       0
# 2    M   blue  female  117.0   300.0       1
# 3    M  green  female  129.0   415.0       0
# 4    M    red  female   79.0   410.0       1
# 5    M  green    male   89.0   415.0       0

# %%
df.rename(columns = {'bought':'bought_yes'})
# Out:
#   size  color  gender  price  weight  bought_yes
# 0   XL    red  female  199.0   500.0           1
# 1    L  green    male   89.0   450.0           0
# 2    M   blue  female  117.0   300.0           1
# 3    M  green  female  129.0   415.0           0
# 4    M    red  female   79.0   410.0           1
# 5    M  green    male   89.0   415.0           0

# %%
df = pd.get_dummies(data = df, drop_first = True).astype('int')
df
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0    199     500       1       0        1            0          1            0
# 1     89     450       0       0        0            1          0            1
# 2    117     300       1       1        0            0          0            0
# 3    129     415       0       1        0            1          0            0
# 4     79     410       1       1        0            0          1            0
# 5     89     415       0       1        0            1          0            1

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

df[['price', 'weight']] = scaler.fit_transform(df[['price', 'weight']])
df
# Out:
#       price    weight  bought  size_M  size_XL  color_green  color_red  \
# 0  2.020743  1.413399       1       0        1            0          1
# 1 -0.690010  0.581988       0       0        0            1          0
# 2  0.000000 -1.912245       1       1        0            0          0
# 3  0.295718  0.000000       0       1        0            1          0
# 4 -0.936442 -0.083141       1       1        0            0          1
# 5 -0.690010  0.000000       0       1        0            1          0
#
#    gender_male
# 0            0
# 1            1
# 2            0
# 3            0
# 4            0
# 5            1

# %%
df.iloc[1,1]
# Out:
# np.float64(0.5819876952473779)

# %%
df.loc[2, "size_M"]
# Out:
# np.int64(1)

# %%
df.loc[5, "gender_male"]
# Out:
# np.int64(1)

# %%
a = pd.Series(data = [1, 32, 32, 33, 0, 19, -23], name = 'b')

# %%
a
# Out:
# 0     1
# 1    32
# 2    32
# 3    33
# 4     0
# 5    19
# 6   -23
# Name: b, dtype: int64

# %%
a
# Out:
# 0     1
# 1    32
# 2    32
# 3    33
# 4     0
# 5    19
# 6   -23
# Name: b, dtype: int64

# %%
dates = pd.date_range("20130101", periods=7, name = 'dates')
a.index = dates

# %%
a
# Out:
# dates
# 2013-01-01     1
# 2013-01-02    32
# 2013-01-03    32
# 2013-01-04    33
# 2013-01-05     0
# 2013-01-06    19
# 2013-01-07   -23
# Freq: D, Name: b, dtype: int64
